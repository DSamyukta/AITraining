# %%
import pandas as pd
import numpy as np

# %%
user_demographics = pd.read_csv('user_demographics.csv')

# %%
user_demographics
# Out:
#       User_ID Gender    Age  Occupation
# 0     1000001      F   0-17          10
# 1     1000002      M    55+          16
# 2     1000003      M  26-35          15
# 3     1000004      M  46-50           7
# 4     1000005      M  26-35          20
# ...       ...    ...    ...         ...
# 5886  1004588      F  26-35           4
# 5887  1004871      M  18-25          12
# 5888  1004113      M  36-45          17
# 5889  1005391      M  26-35           7
# 5890  1001529      M  18-25           4
#
# [5891 rows x 4 columns]

# %%
User_product_purchase_details = pd.read_csv('User_product_purchase_details_p2.csv')

# %%
User_product_purchase_details
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042             A                          2
# 1       1000001  P00248942             A                          2
# 2       1000001  P00087842             A                          2
# 3       1000001  P00085442             A                          2
# 4       1000002  P00285442             C                         4+
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# ...

# %%
unique_userIds = pd.concat([User_product_purchase_details['User_ID']]).unique()

# %%
unique_userIds = pd.Series(unique_userIds)

# %%
describe = User_product_purchase_details.describe()

# %%
describe
# Out:
#             User_ID  Marital_Status  Product_Category_1  Product_Category_2  \
# count  5.500680e+05   550068.000000       550068.000000       376430.000000
# mean   1.003029e+06        0.409653            5.404270            9.842329
# std    1.727592e+03        0.491770            3.936211            5.086590
# min    1.000001e+06        0.000000            1.000000            2.000000
# 25%    1.001516e+06        0.000000            1.000000            5.000000
# 50%    1.003077e+06        0.000000            5.000000            9.000000
# 75%    1.004478e+06        1.000000            8.000000           15.000000
# max    1.006040e+06        1.000000           20.000000           18.000000
#
#        Product_Category_3       Purchase
# count       166821.000000  550068.000000
# mean            12.668243    9263.968713
# std              4.125338    5023.065394
# min              3.000000      12.000000
# 25%              9.000000    5823.000000
# ...

# %%
max_product1 = User_product_purchase_details[User_product_purchase_details['Product_Category_1'] == describe['Product_Category_1']['max']]

# %%
max_product1
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 545915  1000001  P00375436             A                          2
# 545916  1000002  P00372445             C                         4+
# 545917  1000004  P00375436             B                          2
# 545918  1000006  P00375436             A                          1
# 545919  1000007  P00372445             B                          1
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 545915               0                  20                 NaN
# ...

# %%
max_product2 = pd.DataFrame(User_product_purchase_details[User_product_purchase_details['Product_Category_2'] == describe['Product_Category_2']['max']])

# %%
max_product3 = User_product_purchase_details[User_product_purchase_details['Product_Category_3'] == describe['Product_Category_3']['max']]

# %%
max_purchase = User_product_purchase_details[User_product_purchase_details['Purchase'] == describe['Purchase']['max']]

# %%
print(max_purchase['User_ID'])
# Out:
# 87440     1001474
# 93016     1002272
# 370891    1003160
# Name: User_ID, dtype: int64

# %%
type(max_product3['User_ID'])
# Out:
# pandas.core.series.Series

# %%
max_product1
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 545915  1000001  P00375436             A                          2
# 545916  1000002  P00372445             C                         4+
# 545917  1000004  P00375436             B                          2
# 545918  1000006  P00375436             A                          1
# 545919  1000007  P00372445             B                          1
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 545915               0                  20                 NaN
# ...

# %%
max_product2
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 1301    1000208  P00343042             C                          1
# 1302    1000208  P00326242             C                          1
# 2133    1000333  P00343042             A                          0
# 2199    1000343  P00041942             B                          2
# 2242    1000349  P00111242             C                          0
# ...         ...        ...           ...                        ...
# 544705  1005848  P00111242             A                          0
# 545155  1005923  P00111242             C                          1
# 545526  1005981  P00111242             C                          3
# 545567  1005990  P00323542             B                          1
# 545662  1006002  P00326242             C                          1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 1301                 1                   5                18.0
# ...

# %%
max_product3
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 142     1000027  P00281742             C                          1
# 734     1000139  P00121342             C                          2
# 837     1000150  P00057742             B                          0
# 926     1000163  P00128042             A                          1
# 1379    1000223  P00057742             B                         4+
# ...         ...        ...           ...                        ...
# 545453  1005972  P00057742             B                          0
# 545515  1005980  P00282442             C                          3
# 545628  1006000  P00057742             B                          2
# 545739  1006011  P00282442             C                          3
# 545900  1006039  P00282442             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 142                  1                   5                 8.0
# ...

# %%
print(max_product1['User_ID'])
# Out:
# 545915    1000001
# 545916    1000002
# 545917    1000004
# 545918    1000006
# 545919    1000007
#            ...
# 550063    1006033
# 550064    1006035
# 550065    1006036
# 550066    1006038
# 550067    1006039
# Name: User_ID, Length: 2550, dtype: int64

# %%
max_uniqueIds = pd.concat([max_product1['User_ID'], max_product2['User_ID'], max_product3['User_ID'], max_purchase['User_ID']]).unique()

# %%
len(max_uniqueIds)
# Out:
# 4142

# %%
4142/5891
# Out:
# 0.7031064335426922

# %%
purchase_above_15k = User_product_purchase_details[User_product_purchase_details['Purchase'] >= 15000]
product_purchase3 = pd.Series(list(set(purchase_above_15k['User_ID']) & set(max_uniqueIds)))

# %%
len(purchase_above_15k)
# Out:
# 110523

# %%
len(set(product_purchase3))
# Out:
# 4082

# %%
4082/5891
# Out:
# 0.6929214055338652

# %%
purchase_above_20k = User_product_purchase_details[User_product_purchase_details['Purchase'] >= 20000]
product_purchase2 = pd.Series(list(set(purchase_above_20k['User_ID']) & set(max_uniqueIds)))
len(set(product_purchase2))
# Out:
# 2711

# %%
2711/5891
# Out:
# 0.4601935155321677

# %%
purchase_above_225 = User_product_purchase_details[User_product_purchase_details['Purchase'] >= 22500]
product_purchase1 = pd.Series(list(set(purchase_above_225['User_ID']) & set(max_uniqueIds)))
len(set(product_purchase1))
# Out:
# 1117

# %%
1117/5891
# Out:
# 0.18961127143099643

# %%
import matplotlib.pyplot as plt
 
# x axis values
x = [150 ,200 ,225, 5891]
# corresponding y axis values
y = [(4082 - (2711 + 1117))/5891, (2711-1117)/5891, 1117/5891, 1]
 
# plotting the points
plt.scatter(x, y)
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
 
# giving a title to my graph
plt.title('My first graph!')
 
# function to show the plot
plt.show()

# %%
4082 - (2711 + 1117) + (2711-1117) + 1117

# %%
product_purchase1
# Out:
# 0       1003521
# 1       1001474
# 2       1005570
# 3       1005574
# 4       1001483
#          ...
# 1112    1005557
# 1113    1001465
# 1114    1003516
# 1115    1005565
# 1116    1005567
# Length: 1117, dtype: int64

# %%
for i in range(1117):
    product_purchase1[i]

# %%
df = pd.DataFrame(product_purchase1, columns = ['User_ID'])

# %%
df
# Out:
#       User_ID
# 0     1003521
# 1     1001474
# 2     1005570
# 3     1005574
# 4     1001483
# ...       ...
# 1112  1005557
# 1113  1001465
# 1114  1003516
# 1115  1005565
# 1116  1005567
#
# [1117 rows x 1 columns]

# %%
s2 = pd.DataFrame()
x = []
for i in df['User_ID']:
    s2 = pd.concat([s2, user_demographics[user_demographics['User_ID'] == i]])
s2
# Out:
#       User_ID Gender    Age  Occupation
# 3092  1003521      M  26-35           0
# 1312  1001474      M  26-35           4
# 4907  1005570      M  26-35           1
# 4911  1005574      M  26-35           0
# 1320  1001483      M  18-25           4
# ...       ...    ...    ...         ...
# 4895  1005557      M  36-45          14
# 1304  1001465      M  51-55          16
# 3088  1003516      M  18-25           4
# 4903  1005565      M  18-25          17
# 4905  1005567      M  51-55           3
#
# [1117 rows x 4 columns]

# %%
i = 1005567
user_demographics[user_demographics['User_ID'] == i]
# Out:
#       User_ID Gender    Age  Occupation
# 4905  1005567      M  51-55           3

# %%
purchase_above_15k = User_product_purchase_details[User_product_purchase_details['Purchase'] >= 15000]
product_purchase3 = pd.Series(list(set(purchase_above_15k['User_ID']) & set(max_uniqueIds)))
